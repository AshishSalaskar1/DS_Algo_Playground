# %% [markdown]
# ### 1. Write a function that inputs a number and prints the multiplication table of that number

# %%
def m_table(n,times):
  res = [n*i for i in range(1,times+1)]
  for i,x in enumerate(res):
    print("%d x %d = %d"%(n,i+1,x))

# %%
m_table(8,10)
# Out:
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80

# %% [markdown]
# ## Adapter

# %% [markdown]
# ## Bridge

# %% [markdown]
# ## Composite

# %% [markdown]
# ## Decorator

# %% [markdown]
# ## Facade

# %% [markdown]
# ## Flyweight

# %% [markdown]
# ## Proxy

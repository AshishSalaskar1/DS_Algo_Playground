# %% [markdown]
# ## Chain of Responsibility

# %% [markdown]
# ## Command

# %% [markdown]
# ## Iterator

# %% [markdown]
# ## Mediator

# %% [markdown]
# ## Memento

# %% [markdown]
# ## Observer

# %% [markdown]
# ## State

# %% [markdown]
# ## Strategy

# %% [markdown]
# ## Template Method

# %% [markdown]
# ## Visitor
